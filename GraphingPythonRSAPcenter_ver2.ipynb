# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
runFitness = pd.read_csv("PS1_RSA_GenerationBestFitnesses.csv",header=None)
print(runFitness)
# Out:
#           0        1        2        3        4        5        6        7   \
# 0    515.924  474.673  515.822  555.487  537.191  515.815  563.352  465.091
# 1    515.924  474.673  515.822  555.487  537.191  515.815  563.352  465.091
# 2    515.924  474.673  515.822  555.487  537.191  515.815  563.352  465.091
# 3    515.924  474.673  515.822  555.487  537.191  515.815  563.352  465.091
# 4    515.924  474.673  515.822  555.487  537.191  515.815  563.352  465.091
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 496  341.138  437.691  427.705  457.348  537.062  441.256  428.046  456.316
# 497  341.138  437.691  427.705  457.348  537.062  441.256  428.046  456.316
# 498  341.138  437.691  427.705  457.348  537.062  441.256  428.046  456.316
# 499  341.138  437.691  427.705  457.348  537.062  441.256  428.046  456.316
# 500  341.138  437.691  427.705  457.348  537.062  441.256  428.046  456.316
#
#           8        9   ...       20       21       22       23       24  \
# 0    531.195  506.959  ...  487.284  500.206  545.208  558.301  498.414
# 1    531.195  506.959  ...  487.284  500.206  545.208  558.301  498.414
# 2    531.195  506.959  ...  487.284  500.206  545.208  558.301  498.414
# 3    531.195  506.959  ...  487.284  500.206  545.208  558.301  498.414
# 4    531.195  506.959  ...  487.284  500.206  545.208  558.301  498.414
# ..       ...      ...  ...      ...      ...      ...      ...      ...
# 496  448.939  506.959  ...  441.536  280.669  444.691  534.949  467.054
# 497  448.939  506.959  ...  441.536  280.669  444.691  534.949  467.054
# 498  448.939  506.959  ...  441.536  280.669  444.691  534.949  467.054
# 499  448.939  506.959  ...  441.536  280.669  444.691  534.949  467.054
# 500  448.939  506.959  ...  441.536  280.669  444.691  534.949  467.054
#
#           25       26       27       28       29
# 0    538.953  522.122  494.224  527.696  486.083
# 1    538.953  522.122  494.224  527.696  486.083
# 2    538.953  522.122  494.224  527.696  486.083
# 3    538.953  522.122  494.224  527.696  486.083
# 4    538.953  522.122  494.224  527.696  486.083
# ..       ...      ...      ...      ...      ...
# 496  514.126  468.548  438.789  527.696  407.800
# 497  514.126  468.548  438.789  527.696  407.800
# 498  514.126  468.548  438.789  527.696  407.800
# 499  514.126  468.548  438.789  527.696  407.800
# 500  514.126  468.548  438.789  527.696  407.800
#
# [501 rows x 30 columns]

# %%
num_iters = 501
x = np.linspace(0, num_iters,num_iters)

for i in range(0,len(runFitness.iloc[0])):
    plt.plot(x,runFitness[i],'g-')

# %%
TX = pd.read_csv("Tagum_X.csv",header=None, skiprows=1)
TY = pd.read_csv("Tagum_Y.csv",header=None, skiprows=1)
print(TX)
# Out:
#                  0
# 0      810851.0339
# 1      810984.3794
# 2      812972.1837
# 3      811332.2402
# 4      811080.2895
# ...            ...
# 60241  809575.0822
# 60242  809698.9635
# 60243  809690.8592
# 60244  809687.1022
# 60245  809158.9023
#
# [60246 rows x 1 columns]

# %%
plt.plot(TX, TY, 'x', color='black',markersize=.2);
plt.title('Demand points based on Tagum \n City, Philippines Household Data.')
plt.xlabel('x-coordinate')
plt.ylabel('y-coordinate')
plt.savefig('TagumFullXY.jpg',dpi=300,bbox_inches='tight')

# %%
initXValues = pd.read_csv("PS1_RSA_InitBestX.csv",header=None)
initYValues = pd.read_csv("PS1_RSA_InitBestY.csv",header=None)

# %%
bestXValues = pd.read_csv("PS1_RSA_FinalBestX.csv",header=None)
bestYValues = pd.read_csv("PS1_RSA_FinalBestY.csv",header=None)
#print(bestXValues)
#print(bestYValues)

# %%
import numpy as np
A=runFitness.iloc[500]
index_min = np.argmin(A)
print(index_min)
# Out:
# 21

# %%
# print(index_min)

#DX = pd.read_csv("Davao_X_WithoutHeader.csv",header=None)
#DY = pd.read_csv("Davao_Y_WithoutHeader.csv",header=None)

TX = pd.read_csv("Digos_X.csv",header=None, skiprows=1)
TY = pd.read_csv("Digos_Y.csv",header=None, skiprows=1)

# TagumFullX = pd.read_csv("TagumFullX.csv",header=None)
# TagumFullY = pd.read_csv("TagumFullY.csv",header=None)

# # get the initial points of index_min
SpointsX = pd.read_csv("PS1_RSA_InitBestX.csv",header=None)
SpointsY = pd.read_csv("PS1_RSA_InitBestY.csv",header=None)
spx=SpointsX.iloc[index_min]
spy=SpointsY.iloc[index_min]

# # get the best points of index_min
xValues = pd.read_csv("PS1_RSA_FinalBestX.csv",header=None)
yValues = pd.read_csv("PS1_RSA_FinalBestY.csv",header=None)
bestX=xValues.iloc[index_min]
bestY=yValues.iloc[index_min]

# %%
####PROBLEM WITH INITIAL POINTS####

plt.gca().set_aspect('equal', adjustable='box')
ax = plt.gca()

ax.set_ylim([min(yValues.iloc[index_min])-500,max(yValues.iloc[index_min])+1000])
ax.set_xlim([min(xValues.iloc[index_min])-1000,max(xValues.iloc[index_min])+1000])

# Plotting of demand poiints
plt.scatter(TX,TY,color='black', marker='o',s=1)

# Plotting of best facilities
plt.scatter(bestX,bestY,color='red', marker='^')

# Plotting of initial facilities
plt.scatter(spx,spy,color='green')

# # plot the radius/fitness of the best
circle1=plt.Circle(( bestX[0],bestY[0]), runFitness[index_min][4], fill=False,color='r')
circle2=plt.Circle((bestX[1],bestY[1]), runFitness[index_min][4], fill=False,color='r')
circle3=plt.Circle((bestX[2],bestY[2]), runFitness[index_min][4], fill=False,color='r')
circle4=plt.Circle(( bestX[3],bestY[3]), runFitness[index_min][4], fill=False,color='r')
circle5=plt.Circle((bestX[4],bestY[4]), runFitness[index_min][4], fill=False,color='r')
circle6=plt.Circle((bestX[5],bestY[5]), runFitness[index_min][4], fill=False,color='r')
ax.add_artist(circle1)
ax.add_artist(circle2)
ax.add_artist(circle3)
ax.add_artist(circle4)
ax.add_artist(circle5)
ax.add_artist(circle6)

# #plot the radius/fitness of the initial points
circle1=plt.Circle((spx[0], spy[0]), runFitness[index_min][0], fill=False,color='g')
circle2=plt.Circle((spx[1], spy[1]), runFitness[index_min][0], fill=False,color='g')
circle3=plt.Circle((spx[2], spy[2]), runFitness[index_min][0], fill=False,color='g')
circle4=plt.Circle((spx[3], spy[3]), runFitness[index_min][0], fill=False,color='g')
circle5=plt.Circle((spx[4], spy[4]), runFitness[index_min][0], fill=False,color='g')
circle6=plt.Circle((spx[5], spy[5]), runFitness[index_min][0], fill=False,color='g')
ax.add_artist(circle1)
ax.add_artist(circle2)
ax.add_artist(circle3)
ax.add_artist(circle4)
ax.add_artist(circle5)
ax.add_artist(circle6)


# # # plt.scatter(bestX,bestY,color='red', marker='^')

plt.title('Initial (green) and final locations (red) from \n RSA for 6-center on Tagum City data \n maxiter = 500')
# # # plt.title('Initial locations (green) from \n IMO for 6-center on Italy data \n maxiter = 800 and maxrun = 10')
# # # plt.title('Final locations (red) from \n IMO for 6-center on Italy data \n maxiter = 800 and maxrun = 10')
plt.text(811500,822400,"End Fitness ={:05.3f}".format(runFitness[index_min][500]),color='red') 
plt.text(811500,822500,"Init Fitness ={:05.3f}".format(runFitness[index_min][0]),color='green') 
plt.text("End Fitness ={:05.3f}".format(runFitness[index_min][500]),color='red') 
plt.text("Init Fitness ={:05.3f}".format(runFitness[index_min][0]),color='green') 
plt.xticks(rotation = 35)
plt.xlabel('x coordinate')
# # # plt.legend()
plt.ylabel('y coordinate')

# # plt.show
plt.savefig('PS1_RSA_startend6center.jpg',dpi=300,bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [35], line 54
#      52 plt.text(811500,822400,"End Fitness ={:05.3f}".format(runFitness[index_min][500]),color='red')
#      53 plt.text(811500,822500,"Init Fitness ={:05.3f}".format(runFitness[index_min][0]),color='green')
# ---> 54 plt.text("End Fitness ={:05.3f}".format(runFitness[index_min][500]),color='red')
#      55 plt.text("Init Fitness ={:05.3f}".format(runFitness[index_min][0]),color='green')
#      56 plt.xticks(rotation = 35)
#
# TypeError: text() missing 2 required positional arguments: 'y' and 's'

# %%
finalFitness=[]
maxiter=500
for i in range(0,len(runFitness.iloc[0])):
    finalFitness.append(runFitness[i][maxiter])
x = np.linspace(1, len(finalFitness),len(finalFitness))

plt.bar(x, finalFitness)
plt.ylabel('Maximum Distance')
plt.xlabel('Run Number')
plt.title('Final Maximum Distance per run for 6-center problem on Davao City \n data  using RSA with maxiter = {0}'.format(maxiter))

plt.savefig('FinalFitValCC1_6center.jpg',dpi=300)
